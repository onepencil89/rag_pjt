# %% [markdown]
# # 환경 변수 로딩

# %% [markdown]
# ## 와인 reviewdata indexing
# -vectorDB : pinecone

# %%
from dotenv import load_dotenv
import os
load_dotenv(override=True, dotenv_path="../.env")

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
PINECONE_API_KEY = os.getenv("PINECONE_API_KEY")
OPENAI_EMBEDDING_MODEL = os.getenv("OPENAI_EMBEDDING_MODEL")
PINECONE_INDEX_NAME = os.getenv("PINECONE_INDEX_NAME")
PINECONE_NAMESPACE = os.getenv("PINECONE_NAMESPACE")

# %% [markdown]
# ## doc loader

# %%
from langchain_community.document_loaders import CSVLoader
import os

csv_path = r"C:/google_drive/KPMG_7th_lab/rag_pjt/prepare/wine_reviews/winemag-data-130k-v2.csv"
loader = CSVLoader(csv_path)

# %%
docs = loader.load()
for i, d in enumerate(docs[:3]):
    print(i, d)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# File ~\miniconda3\envs\lc_env\Lib\site-packages\langchain_community\document_loaders\csv_loader.py:135, in CSVLoader.lazy_load(self)
#     134     with open(self.file_path, newline="", encoding=self.encoding) as csvfile:
# --> 135         yield from self.__read_file(csvfile)
#     136 except UnicodeDecodeError as e:
#
# File ~\miniconda3\envs\lc_env\Lib\site-packages\langchain_community\document_loaders\csv_loader.py:155, in CSVLoader.__read_file(self, csvfile)
#     154 csv_reader = csv.DictReader(csvfile, **self.csv_args)
# --> 155 for i, row in enumerate(csv_reader):
#     156     try:
#
# File ~\miniconda3\envs\lc_env\Lib\csv.py:115, in DictReader.__next__(self)
#     113 if self.line_num == 0:
#     114     # Used only for its side effect.
# --> 115     self.fieldnames
#     116 row = next(self.reader)
#
# File ~\miniconda3\envs\lc_env\Lib\csv.py:102, in DictReader.fieldnames(self)
#     101 try:
# --> 102     self._fieldnames = next(self.reader)
#     103 except StopIteration:
#
# UnicodeDecodeError: 'cp949' codec can't decode byte 0xe2 in position 360: illegal multibyte sequence
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 docs = loader.load()
#       2 for i, d in enumerate(docs[:3]):
#       3     print(i, d)
#
# File ~\miniconda3\envs\lc_env\Lib\site-packages\langchain_core\document_loaders\base.py:43, in BaseLoader.load(self)
#      37 def load(self) -> list[Document]:
#      38     """Load data into `Document` objects.
#      39
#      40     Returns:
#      41         The documents.
#      42     """
# ---> 43     return list(self.lazy_load())
#
# File ~\miniconda3\envs\lc_env\Lib\site-packages\langchain_community\document_loaders\csv_loader.py:149, in CSVLoader.lazy_load(self)
#     147                 continue
#     148     else:
# --> 149         raise RuntimeError(f"Error loading {self.file_path}") from e
#     150 except Exception as e:
#     151     raise RuntimeError(f"Error loading {self.file_path}") from e
#
# RuntimeError: Error loading C:/google_drive/KPMG_7th_lab/rag_pjt/prepare/wine_reviews/winemag-data-130k-v2.csv
